# %%
# !git clone https://github.com/IZ-f-AI-ss3/Denoising_in_score_based_generative_models.git
# %cd /kaggle/working/Denoising_in_score_based_generative_models/

# %%
# !git pull

# %%
# !pip install gdown
# !pip install tensorboardX  # pyyaml

import sys
sys.path.append('/kaggle/working/Denoising_in_score_based_generative_models')

# !gdown https://drive.google.com/uc?id=1BF2mwFv5IRCGaQbEWTbLlAOWEkNzMe5O
# !unzip run.zip -d /kaggle/working/Denoising_in_score_based_generative_models/

# %%
# !python main.py --runner BaselineRunner --test -o samples  --doc celeba --sampling ordinary_langevin

# %%
# !python -m main --runner ToyRunner --config toy.yml --doc toy_exp
# !python main.py --runner BaselineRunner --config half_denoising_baseline.yml --doc mnist

# !python main.py --runner AnnealRunner --test -o samples  --doc celeba --sampling half_denoising --seed 456

# !python main.py --runner AnnealRunner --heavy_test -o samples --doc celeba --n_samples 200 --sampling_type ordinary --seed 3189 #half_denoising #  #50000

# Warning : it took 15 minutes for 2 batchs (200 samples) and we need 50k samples (cifar-10) ???

# %%
# !zip -r samples_ordinary.zip /kaggle/working/Denoising_in_score_based_generative_models/samples

# %%
from IPython.display import FileLink
FileLink('samples_ordinary.zip')
